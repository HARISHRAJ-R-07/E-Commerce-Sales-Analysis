# %% [markdown]
# <a href="https://colab.research.google.com/github/HARISHRAJ-R-07/E-Commerce-Sales-Analysis/blob/main/E_Commerce_Sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🛒 E-Commerce Sales Analysis
#
# A practical **Data Analysis project** built with Python to explore and understand e-commerce sales data. The project transforms raw sales data into **meaningful business insights** through data cleaning, analysis, and visualization.
#
# ### 🎯 Project Objectives
#
# * 🧹 **Data Cleaning** — Handle missing values, duplicates, and inconsistent data.
# * 💰 **Revenue Analysis** — Calculate and analyze overall sales revenue.
# * 🛍️ **Product Analysis** — Identify top-performing and low-performing products.
# * 📦 **Category Analysis** — Compare sales performance across product categories.
# * 🌍 **Regional Analysis** — Understand revenue generated from different regions.
# * 📅 **Time-Based Analysis** — Analyze monthly sales trends and patterns.
# * 📊 **Data Visualization** — Create meaningful charts using Matplotlib and Seaborn.
# * 💡 **Business Insights** — Extract actionable insights to support better decision-making.
#
# ### 🛠️ Tools & Technologies
#
# * 🐍 **Python**
# * 🐼 **Pandas** — Data manipulation and analysis
# * 🔢 **NumPy** — Numerical computations
# * 📈 **Matplotlib** — Data visualization
# * 🎨 **Seaborn** — Statistical visualization
# * 📓 **Jupyter Notebook / Google Colab**
#
# ### 🔍 Key Analysis
#
# * 📌 Total Revenue
# * 📌 Revenue by Category
# * 📌 Revenue by Region
# * 📌 Top 10 Products
# * 📌 Monthly Revenue Trends
# * 📌 Sales Performance Patterns
#
# ### 🚀 Conclusion
#
# This project provides hands-on experience in **real-world data analysis** and demonstrates how Python can be used to transform raw e-commerce data into **clear visualizations, valuable insights, and data-driven business decisions**.

# %%
from pandas.core.indexes import category
# 1. Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Load dataset
df = pd.read_csv("ecommerce_sales.csv")

# 3. Basic information
print(df.head())
print(df.info())
print(df.isnull().sum())

# 4. Data cleaning
df.drop_duplicates(inplace=True)
df["Order_Date"] = pd.to_datetime(df["Order_Date"])

# 5. Create Revenue
df["Revenue"] = df["Quantity"] * df["Unit_Price"] * (1 - df["Discount"])

# 6. Basic statistics
print(df.describe())

# 7. Revenue by category
print(df.groupby("Category")["Revenue"].sum())

# 8. Revenue by region
print(df.groupby("Region")["Revenue"].sum())

# 9. Top products
print(df.groupby("Product")["Revenue"]
      .sum().sort_values(ascending=False).head(10))

# 10. Visualization
sns.barplot(data=df, x="Category", y="Revenue", ci=None, hue = "Category")
plt.xlabel("Category")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.title("Revenue by Category")
plt.show()

# 11. Monthly sales
monthly_sales = df.groupby(
    df["Order_Date"].dt.month
)["Revenue"].sum()

monthly_sales.plot(kind="line", marker="o")
plt.title("Monthly Revenue")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()
# Out:
#   Order_ID  Order_Date Customer_ID          Product Category  Quantity  \
# 0  ORD0001  2025-01-21     CUST083        Face Wash   Beauty         3
# 1  ORD0002  2025-09-15     CUST088  Statistics Book    Books         3
# 2  ORD0003  2025-01-22     CUST089        Face Wash   Beauty         1
# 3  ORD0004  2025-07-07     CUST080         Backpack  Fashion         2
# 4  ORD0005  2025-11-03     CUST007          Perfume   Beauty         1
#
#    Unit_Price  Discount   Region Payment_Method
# 0       399.0      0.15     East     Debit Card
# 1       699.0      0.00     West    Credit Card
# 2       399.0      0.05    North     Debit Card
# 3      1299.0      0.00     East    Net Banking
# 4      1599.0      0.00  Central            UPI
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        250 non-null    object
# ...

# %%
# After cleaning dataset

df
# Out:
#     Order_ID Order_Date Customer_ID           Product Category  Quantity  \
# 0    ORD0001 2025-01-21     CUST083         Face Wash   Beauty         3
# 1    ORD0002 2025-09-15     CUST088   Statistics Book    Books         3
# 2    ORD0003 2025-01-22     CUST089         Face Wash   Beauty         1
# 3    ORD0004 2025-07-07     CUST080          Backpack  Fashion         2
# 4    ORD0005 2025-11-03     CUST007           Perfume   Beauty         1
# ..       ...        ...         ...               ...      ...       ...
# 245  ORD0246 2025-04-08     CUST004     Python Basics    Books         1
# 246  ORD0247 2025-12-31     CUST075      Water Bottle     Home         1
# 247  ORD0248 2025-07-18     CUST015  Machine Learning    Books         1
# 248  ORD0249 2025-08-12     CUST035         Face Wash   Beauty         1
# 249  ORD0250 2025-09-22     CUST003          Backpack  Fashion         2
#
#      Unit_Price  Discount   Region Payment_Method  Revenue
# ...
